# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import arabic_reshaper
from bidi.algorithm import get_display

def ar(text):
    return get_display(arabic_reshaper.reshape(text))


# Arabian region boundaries
ARAB_LAT_MIN, ARAB_LAT_MAX = 0.0, 40.0
ARAB_LON_MIN, ARAB_LON_MAX = -20.0, 60.0



plt.rcParams.update({"font.size": 14})

fig = plt.figure(figsize=(14, 7), dpi=300)
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_global()



ax.add_feature(cfeature.LAND, facecolor="lightgray", alpha=0.3)
ax.add_feature(cfeature.OCEAN, facecolor="white")
ax.add_feature(cfeature.COASTLINE, linewidth=0.8)
ax.add_feature(cfeature.BORDERS, linewidth=0.5)


# Arabian region box
arab_box = mpatches.Rectangle(
    (ARAB_LON_MIN, ARAB_LAT_MIN),
    ARAB_LON_MAX - ARAB_LON_MIN,
    ARAB_LAT_MAX - ARAB_LAT_MIN,
    fill=False,
    edgecolor="black",
    linewidth=2.5,
    transform=ccrs.PlateCarree()
)
ax.add_patch(arab_box)



gl = ax.gridlines(
    draw_labels=True,
    linewidth=0.4,
    color="gray",
    alpha=0.5,
    linestyle="--"
)
gl.top_labels = False
gl.right_labels = False
gl.xlabel_style = {"size": 14}
gl.ylabel_style = {"size": 14}



ax.text(
    0.5, -0.08,
    ar("خطوط الطول"),
    transform=ax.transAxes,
    ha="center",
    va="top",
    fontsize=14
)

ax.text(
    -0.06, 0.5,
    ar("خطوط العرض"),
    transform=ax.transAxes,
    ha="center",
    va="center",
    rotation=90,
    fontsize=14
)

# Title
ax.set_title(
    ar("خريطة العالم مع تحديد نطاق المنطقة العربية"),
    fontsize=14
)

plt.tight_layout()
plt.show()

# %%
boundaries = {
    "Latitude (°N)": (0.0, 40.0),
    "Longitude (°E)": (-20.0, 60.0)
}

for k, v in boundaries.items():
    print(f"{k}: {v[0]} → {v[1]}")
# Out:
# Latitude (°N): 0.0 → 40.0
# Longitude (°E): -20.0 → 60.0
